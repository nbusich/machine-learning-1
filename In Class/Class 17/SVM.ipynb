# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([[0,2],
              [0,1],
              [1,0],
              [3,4],
              [5,2],
              [5,3]])
y = np.array([[-1],[-1],[-1],[1],[1],[1]])

plt.scatter(X[:,0], X[:,1], c = y)
plt.show()

# %%
alpha = 0.01
def SVM(X, y):
    w = (X.T @ y)/2
    return w
    
def dW(x, y , w):
    return 2*w - X.T.dot(y)

def db(y):
    return np.sum(y)

def gd(X, y):
    w = np.array([[0], [1]])
    for i in range(100):
        w = alpha * dW(X, y, w)
        return w
    
print(gd(X, y))
print(SVM(X, y))
# Out:
# [[-0.12]
#  [-0.04]]
# [[6.]
#  [3.]]
