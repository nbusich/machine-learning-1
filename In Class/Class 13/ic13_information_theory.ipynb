# %%
from lib2to3.fixes.fix_metaclass import FixMetaclass
from mailbox import MMDFMessage

import numpy as np
import math as m

from fontTools.cffLib import FDSelectCompiler

I = m.log(1/0.95)
print("Info if Kate wins: ", I)

I = m.log(1/0.0499)
print("Info if Matt wins: ", I)

I = m.log(1/0.0001)
print("Info if Alice wins: ", I)
# Out:
# Info if Kate wins:  0.05129329438755048
# Info if Matt wins:  2.997734276224664
# Info if Alice wins:  9.210340371976184

# %%
(0.2*2*m.log(1/0.2)) + (0.2*m.log(1/0.2)) + (0.2*m.log(1/0.2)) + (0.2*m.log(1/0.2))
# Out:
# 1.6094379124341005

# %%
A = np.genfromtxt('time_until_phone_drop.csv', delimiter=',')
import autograd.numpy as np
from autograd import grad
print(A)
def f(x):
    func = (x * np.log(1/x))
    return func
grad_f = grad(f)
print(grad_f(A[0]))
# Out:
# [2.365e+00 6.860e-01 2.534e+00 4.120e-01 1.506e+00 6.940e-01 2.402e+00
#  1.225e+00 7.100e-02 1.495e+00 1.120e-01 3.200e-01 2.790e-01 1.143e+00
#  4.280e-01 9.420e-01 1.061e+00 6.290e-01 1.000e-01 1.009e+00 8.900e-02
#  4.120e-01 1.520e-01 2.840e+00 4.080e-01 1.170e-01 3.290e-01 1.820e-01
#  1.581e+00 1.952e+00 2.610e-01 2.120e-01 1.470e-01 1.620e-01 8.840e-01
#  6.310e-01 2.320e-01 2.744e+00 5.580e-01 6.060e-01 3.970e-01 8.910e-01
#  4.600e-02 4.100e-01 1.195e+00 8.380e-01 9.540e-01 4.200e-01 3.310e-01
#  9.600e-02 2.620e-01 6.410e-01 8.320e-01 2.701e+00 9.100e-01 3.150e-01
#  6.610e-01 1.331e+00 6.340e-01 1.525e+00 7.000e-03 4.100e-02 4.060e-01
#  3.710e-01 5.500e-02 8.020e-01 1.150e+00 3.070e-01 1.041e+00 2.600e-01
#  3.363e+00 6.500e-01 1.210e-01 2.259e+00 3.270e-01 2.210e-01 1.960e-01
#  4.940e-01 4.130e-01 2.264e+00 6.390e-01 4.490e-01 2.451e+00 2.454e+00
#  4.360e-01 2.180e-01 2.405e+00 4.800e-02 1.198e+00 1.343e+00 1.410e-01
# ...

# %%
H = 0.6*np.log(1/0.6) + 0.4*np.log(1/0.4)
print("Entropy of P(x): ", H)

H = 0.3*np.log(1/0.3) + 0.5*np.log(1/0.5) + 0.2*np.log(1/0.2)
print("Entropy of P(Y): ", H)

# Cross Entropy
p = [0.1, 0.4, 0.1]
q = [0.2, 0.1, 0.1]
H = (0.1/0.6)*np.log(1/(0.2/0.4)) + (0.4/0.6)*np.log(1/(0.1/0.6)) + (0.1/0.6)*np.log(1/(0.1/0.6))
print("Cross-Entropy H(p,q): ", H)

# KL Divergence
# Out:
# Entropy of P(x):  0.6730116670092565
# Entropy of P(Y):  1.0296530140645737
# Cross-Entropy H(p,q):  1.6086574211167037

# %%
FM = np.genfromtxt('time_until_phone_drop.csv', delimiter=',')
MM = np.genfromtxt('time_until_phone_drop.csv', delimiter=',')
FD = np.genfromtxt('time_until_phone_drop.csv', delimiter=',')
MD = np.genfromtxt('age_met.csv', delimiter=',')
